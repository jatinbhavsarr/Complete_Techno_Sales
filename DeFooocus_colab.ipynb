# %%
#@title DeFooocus
#@markdown **Launch the interface DeFocus (Fooocus fork)** | You need to connect with T4/A100/V100
#@markdown ****
#@markdown *Attention!* When working in the interface with the FaceSwap and CPDS controlnet, crashes are possible; it is also recommended to work in *Extreme speed* mode for additional stability. When working with the ImagePrompt and PyraCanny controls, 85% of the work will be stable.
#@markdown ****

print("[DeFooocus] Preparing ...")

theme = "dark" #@param ["dark", "light"]
preset = "realistic" #@param ["deafult", "realistic", "anime", "lcm", "sai", "turbo", "lighting", "hypersd", "playground_v2.5", "dpo", "spo", "sd1.5"]
advenced_args = "--share --attention-split --always-high-vram --disable-offload-from-vram --all-in-fp16" #@param {type: "string"}

if preset != "deafult":
  args = f"{advenced_args} --theme {theme} --preset {preset}"
else:
  args = f"{advenced_args} --theme {theme}"

# Install pygit2 early as it might be needed for some git operations
# !pip install -q pygit2==1.12.2

# %cd /content
# !rm -rf DeFooocus # Clean up any previous installation
# !git clone https://github.com/ehristoforu/DeFooocus.git
# %cd /content/DeFooocus

# --- Dependency Management for Colab Environment ---
# The goal is to explicitly install core packages in a specific order
# to avoid conflicts, especially with numpy/cupy and onnxruntime-gpu build failures.

# 1. Explicitly uninstall potentially conflicting core packages first
# This ensures we start with a clean slate for these critical dependencies.
# !pip uninstall -y numpy cupy torch torchvision torchaudio xformers onnxruntime onnxruntime-gpu

# 2. Reinstall numpy to a specific version known for compatibility
# !pip install -q numpy==1.23.5 --force-reinstall

# 3. Install cupy specific to Colab's CUDA version
# This version is usually compatible with CUDA 11.x in Colab.
# !pip install -q cupy-cuda11x

# 4. Install torch, torchvision, torchaudio for CUDA 11.8 (common in Colab)
# These versions match DeFooocus's requirements_versions.txt and are built for CUDA 11.8.
# !pip install -q torch==2.1.2 torchvision==0.16.2 torchaudio==2.1.2 --index-url https://download.pytorch.org/whl/cu118

# 5. Install xformers
# This often depends on a correctly installed torch.
# !pip install -q xformers==0.0.23

# 6. Install onnxruntime-gpu
# This was failing to build; installing it explicitly after torch/cuda setup might help.
# !pip install -q onnxruntime-gpu==1.17.0

# 7. Install remaining requirements from requirements_versions.txt
# Pip should ideally skip already installed packages or confirm compatibility.
# !pip install -q -r requirements_versions.txt

print("[DeFooocus] Starting ...")
# !python entry_with_update.py $args
# Out:
# [DeFooocus] Preparing ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 738.5/738.5 kB 16.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#   error: subprocess-exited-with-error
#
#   × Building wheel for pygit2 (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for pygit2
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (pygit2)
# /content
# Cloning into 'DeFooocus'...
# remote: Enumerating objects: 7032, done.
# remote: Total 7032 (delta 0), reused 0 (delta 0), pack-reused 7032 (from 1)
# Receiving objects: 100% (7032/7032), 47.35 MiB | 40.88 MiB/s, done.
# Resolving deltas: 100% (3825/3825), done.
# /content/DeFooocus
# ...
